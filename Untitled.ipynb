# %%
# %matplotlib inline
import aia; reload(aia)
aia.DPI = 96.0
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /usr/local/lib/python2.7/dist-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
net = aia.Network("handbag_64")
# Out:
# LOADING...
# ('n_layers=', 3)
# load model from ./models/handbag_64.dcgan_theano
# 3.13 seconds to load theano models
# COMPILING...
# 0.74 seconds to compile _gen function
# LOADING...
# ('n_layers=', 3)
# load model from ./models/handbag_64.dcgan_theano
# 3.12 seconds to load theano models
# COMPILING...
# 0.46 seconds to compile _gen function
# COMPILING...
# 5.05 seconds to compile _bfgs function
# COMPILING...
# 1.34 seconds to compile _feature function
# COMPILING...
# 1.27 seconds to compile _predict function

# %%
img0 = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/81SYa-aoAcL._UL1500_.jpg")
lv_0 = net.get_lv(img0)
img1 = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/815q3eZoF9L._UL1500_.jpg")
lv_1 = net.get_lv(img1)
img2 = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/71pvQ8fUctL._UL1500_.jpg")
lv_2 = net.get_lv(img2)
img_teal_side = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/61DbhteWtjL._UL1500_.jpg")
lv_teal_side = net.get_lv(img_teal_side)
img_teal_oblique = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/61Dl6ccCj7L._UL1500_.jpg")
lv_teal_oblique = net.get_lv(img_teal_oblique)
img_red_side = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/81dBRJZt4rL._UL1500_.jpg")
lv_red_side = net.get_lv(img_red_side)
img_red_oblique = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/81vvqB2375L._UL1500_.jpg")
lv_red_oblique = net.get_lv(img_red_oblique)
img_purple_side = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/61RO5moBbsL._UL1003_.jpg")
lv_purple_side = net.get_lv(img_purple_side)
img_purple_oblique = aia.get_image(url="https://images-na.ssl-images-amazon.com/images/I/61%2BOTXJ5WsL._UL1134_.jpg")
lv_purple_oblique = net.get_lv(img_purple_oblique)
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:132: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecurePlatformWarning
# process 1 images
# reconstruct 1 images using bfgs
# n_iters = 201, f = 0.122
# process 1 images
# reconstruct 1 images using bfgs
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:132: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# ...

# %%
bag_samples = ["https://images-na.ssl-images-amazon.com/images/I/51Ji-Ak7zqL._AC_SR160,160_.jpg", "https://images-na.ssl-images-amazon.com/images/I/81QnkIj56qL._AC_UL160_SR160,160_.jpg", "https://images-na.ssl-images-amazon.com/images/I/41X-aLqfIxL._AC_SR160,160_.jpg", "https://images-na.ssl-images-amazon.com/images/I/81liVpoAusL._AC_UL160_SR160,160_.jpg", "https://images-na.ssl-images-amazon.com/images/I/51zF16O5SqL._AC_SR160,160_.jpg", "https://images-na.ssl-images-amazon.com/images/I/91KBVpxpTCL._AC_UL160_SR160,160_.jpg"]

# %%
aia.display_image(img_teal_side, scale=0.1)
aia.display_image(img_teal_oblique, scale=0.1)
aia.display_image(img_red_side, scale=0.1)
aia.display_image(img_red_oblique, scale=0.1)
aia.display_image(img_purple_side, scale=0.1)
aia.display_image(img_purple_oblique, scale=0.1)
aia.display_image(img_purple_oblique, scale=0.1)

# %%
z0 = net.get_lv(img0)
img0_approx = net.imagify(z0)
z1 = net.get_lv(img1)
img1_approx = net.imagify(z1)
z2 = net.get_lv(img2)
img2_approx = net.imagify(z2)
aia.display_image(img0_approx)
aia.display_image(img1_approx)
aia.display_image(img2_approx)
# Out:
# process 1 images
# reconstruct 1 images using bfgs
# n_iters = 201, f = 0.124
# process 1 images
# reconstruct 1 images using bfgs
# n_iters = 201, f = 0.112
# process 1 images
# reconstruct 1 images using bfgs
# n_iters = 201, f = 0.152

# %%
vis = net.interpolate_full(img0, img1)
aia.display_image(vis, scale=2.0)
# Out:
# process 1 images
# reconstruct 1 images using bfgs
# n_iters = 154, f = 0.127
# process 1 images
# reconstruct 1 images using bfgs
# n_iters = 177, f = 0.116
# (40, 100)
# (40, 100)
# (40, 3, 64, 64)
# /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:190: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   a = empty(shape, dtype, order)
# lib/utils.py:138: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   img[j * h:j * h + h, i * w:i * w + w, :] = x

# %%
a0 = lv_teal_oblique
a1 = aia.lerp(a0, lv_red_side, 0.5)
b0 = lv_0
b1 = net.analogize(a0, a1, b0)
aia.display_image(net.imagify(a0), scale=1.0)
aia.display_image(net.imagify(a1), scale=1.0)
aia.display_image(net.imagify(lv_red_side), scale=1.0)
aia.display_image(net.imagify(b0), scale=1.0)
aia.display_image(net.imagify(b1), scale=1.0)
